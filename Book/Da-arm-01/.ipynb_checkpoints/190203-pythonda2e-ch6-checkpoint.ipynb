# %%
#데이터 시각화 p.183 ~ /  18:59 ~ 20:30
import matplotlib.pyplot as plt
import numpy as np

# x 좌표를 설정 / 시작 0,마지막 20
x = np.linspace(0, 20)

# 다음 형태로 선을 만듬
plt.plot(x, .5 + x)
plt.plot(x, 1 + 2 *x, '--')
# 화면에 보여줌(저장은 'savefig()'함수 사용)
plt.show()

# %%
#로그 플롯(logarithmic plot)
#로그 눈금(scale)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('ex/transcount.csv')
df = df.groupby('year').aggregate(np.mean)
years = df.index.values
counts = df['trans_count'].values

#데이터 피팅
poly = np.polyfit(years, np.log(counts), deg=1)
#다항식 형태 결과
print("Poly", poly)

#semilogy 함수로 피팅 
plt.semilogy(years, counts, 'o')
plt.semilogy(years, np.exp(np.polyval(poly, years)))
plt.show()
# Out:
# Poly [ 3.61559210e-01 -7.05783195e+02]

# %%
#분산 플롯(scatter plot) => 변수 사이의 상관관계를 보여준다. 
#양 positive
#bubble chart는 분산 플롯의 확장된 형태이다. 

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('ex/transcount.csv')
df

df = df.groupby('year').aggregate(np.mean)

gpu = pd.read_csv('ex/gpu_transcount.csv')
gpu = gpu.groupby('year').aggregate(np.mean)

df = pd.merge(df, gpu, how='outer', left_index=True, right_index =True)

df = df.replace(np.nan, 0)
print(df)

years = df.index.values
counts = df['trans_count'].values
gpu_count = df['gpu_trans_count'].values

cnt_log = np.log(counts)

#알파는 투명도를 뜻함 
plt.scatter(years, cnt_log, c =200 * years, s = 20 +200 * gpu_count /gpu_count.max(), alpha = 0.5)
plt.show()
# Out:
#        trans_count  gpu_trans_count
# year
# 1971  2.300000e+03     0.000000e+00
# 1972  3.500000e+03     0.000000e+00
# 1974  4.533333e+03     0.000000e+00
# 1975  3.510000e+03     0.000000e+00
# 1976  7.500000e+03     0.000000e+00
# 1978  1.900000e+04     0.000000e+00
# 1979  4.850000e+04     0.000000e+00
# 1982  9.450000e+04     0.000000e+00
# 1983  8.500000e+03     0.000000e+00
# 1984  2.000000e+05     0.000000e+00
# 1985  1.053333e+05     0.000000e+00
# 1986  2.500000e+04     0.000000e+00
# 1988  2.500000e+05     0.000000e+00
# 1989  7.401175e+05     0.000000e+00
# 1991  6.900000e+05     0.000000e+00
# 1993  3.100000e+06     0.000000e+00
# 1994  5.789770e+05     0.000000e+00
# 1995  5.500000e+06     0.000000e+00
# 1996  4.300000e+06     0.000000e+00
# 1997  8.150000e+06     3.500000e+06
# 1998  7.500000e+06     0.000000e+00
# 1999  1.760000e+07     1.350000e+07
# 2000  3.150000e+07     2.500000e+07
# 2001  4.500000e+07     5.850000e+07
# 2002  1.375000e+08     8.500000e+07
# 2003  1.900667e+08     1.260000e+08
# 2004  3.520000e+08     1.910000e+08
# 2005  1.690000e+08     3.120000e+08
# 2006  6.040000e+08     5.325000e+08
# 2007  3.716000e+08     7.270000e+08
# 2008  9.032000e+08     1.179500e+09
# 2009  3.450000e+09     2.154000e+09
# 2010  1.511667e+09     2.946667e+09
# 2011  1.733500e+09     4.312712e+09
# 2012  2.014826e+09     5.310000e+09
# 2013  5.000000e+09     6.300000e+09
# 2014  4.310000e+09     0.000000e+00

# %%
#Day9  ~ 202 10:44 ~ 12:28
#범례 및 주석
#legend() 사용해 각 데이터 라벨을 붙임. 

#annotate() 주석 함수.
#title() 제목 함수

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('ex/transcount.csv')
df = df.groupby('year').aggregate(np.mean)

gpu = pd.read_csv('ex/gpu_transcount.csv')
gpu = gpu.groupby('year').aggregate(np.mean)

df = pd.merge(df, gpu, how ='outer', left_index =True, right_index =True)
df = df.replace(np.nan, 0)

years = df.index.values
counts = df['trans_count'].values
gpu_counts = df['gpu_trans_count'].values

poly = np.polyfit(years, np.log(counts), deg = 1)
plt.plot(years, np.polyval(poly, years), label='Fit')

gpu_start = gpu.index.values.min()
y_ann = np.log(df.at[gpu_start, 'trans_count'])
#최소값 찾는 것.
ann_str = "Fist GPU\n %d" % gpu_start
plt.annotate(ann_str, xy=(gpu_start, y_ann), arrowprops =dict(arrowstyle="->"), xytext=(-30, +70), textcoords ='offset points')

cnt_log = np.log(counts)
plt.scatter(years, cnt_log, c=200* years, s =20 +200 * gpu_counts/gpu_counts.max(), alpha=0.5, label="Scatter Plot")
plt.legend(loc = 'upper left')
plt.grid()
plt.xlabel("Year")
plt.ylabel("Log Transistor Counts", fontsize =16)
plt.title ("Moore's Law & Transistor Counts")
plt.show()

# %%
#3차원 플롯 // 에러 뜸.
from mpl_toolkits.mplot3d.axes3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('ex/transcount.csv')
df = df.groupby('year').aggregate(np.mean)

gpu = pd.read_csv('ex/gpu_transcount.csv')
gpu = gpu.groupby('year').aggregate(np.mean)

df = pd.merge(df, gpu, how='outer', left_index=True, right_index=True)
df = df.replace(np.nan, 0)

fig = plt.figure()
ax = Axes3D(fig)

X = df.index.values
Y = np.where(df['trans_count'].values>0, np.log(df['trans_count'].values), 0)
X, Y = np.meshgrid(X, Y)
Z = np.where(df['gpu_trans_count'].values>0, np.log(df['gpu_trans_count'].values),0)



ax.plot_surface(X, Y, Z)
ax.set_xlabel('Year')
ax.set_ylable('Log CPU transistor counts')
ax.set_zlable('Log GPI transistor counts')
ax.set_title("Moore's Law & Transistor Counts")
plt.show()
# Out:
# /Users/siyeon/.pyenv/versions/3.5.2/lib/python3.5/site-packages/ipykernel_launcher.py:22: RuntimeWarning: divide by zero encountered in log
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a2075dad80db> in <module>
#      22 Z = np.where(df['gpu_trans_count'].values>0, np.log(df['gpu_trans_count'].values),0)
#      23
# ---> 24 ax.plot_surface(X, Y, Z)
#      25 ax.set_xlabel('Year')
#      26 ax.set_ylable('Log CPU transistor counts')
#
# ~/.pyenv/versions/3.5.2/lib/python3.5/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1609
#    1610         if Z.ndim != 2:
# -> 1611             raise ValueError("Argument Z must be 2-dimensional.")
#    1612         # TODO: Support masked arrays
#    1613         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
#pandas 플로팅
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('ex/transcount.csv')
df = df.groupby('year').aggregate(np.mean)

gpu = pd.read_csv('ex/gpu_transcount.csv')
gpu = gpu.groupby('year').aggregate(np.mean)

df = pd.merge(df, gpu, how = 'outer', left_index=True, right_index=True)
df = df.replace(np.nan, 0)

df.plot()
#세미-로그 그래프 생성
df.plot(logy=True)
#로그-로그 그래프
df[df['gpu_trans_count']> 0].plot(kind='scatter', x='trans_count', y='gpu_trans_count', loglog=True)
plt.show()

# %%
#지연 플롯 // 에러 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.tools.plotting import lag_plot

df= pd.read_csv('ex/transcount.csv')
df = df.groupby('year').aggregate(np.mean)

gpu = pd.read_csv('ex/gpu_transcount.csv')
gpu = gpu.groupbg('year').aggregate(np.mean)

df = pd.merge(df, gpu, how ='outer', left_index=True , right_index=True)
df = df.replace(np.nan, 0)

lag_plot(np.log(df['trans_count']))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-405866c61dcb> in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from pandas.tools.plotting import lag_plot
#       6
#       7 df= pd.read_csv('ex/transcount.csv')
#
# ImportError: No module named 'pandas.tools'

# %%
#자기상관 플롯

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.tools.plotting import autocorrelation_plot

df = pd.read_csv('transcount.csv')
df = df.groupby('year').aggregate(np.mean)

gpu = pd.read_csv('gpu_transcount.csv')
gpu = gpu.groupby('year').aggregate(np.mean)

df = pd.merge(df, gpu, how='outer', left_index=True, right_index=True)
df = df.replace(np.nan, 0)
#autocorrelation_plot 함수로 자기상관을 만들 수 있음.
autocorrelation_plot(np.log(df['trans_count']))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-c88aa34c678f> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from pandas.tools.plotting import autocorrelation_plot
#       5
#       6 df = pd.read_csv('transcount.csv')
#
# ImportError: No module named 'pandas.tools'
