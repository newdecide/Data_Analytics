# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import time 

review_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={}"


html = urlopen(review_url.format(200))
bsObj = BeautifulSoup(html.read(), "html.parser")

# %%
list1 = bsObj.find_all("div", {"class": "score_result"})
list1
# Out:
# [<div class="score_result">
#  <ul>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p>이 영화는 단순히 빈부에의한 격차뿐만 아니라, 삶을 살아가는데 있어 집단과 개인의 격차도 꿰뚫어 보여준다고 생각합니다. 남들과는 다른 개인으로서 나 자신은 집단에 감히 선을 넘어서는 안된다는 씁쓸한 현실.  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15742074, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>Leonih(rbdu****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:55</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','rbdu****', 'fyiteSOKM5BPfrqWhk4WBvBM6QTtzEdPlyuRELqZuBU=', '이 영화는 단순히 빈부에의한 격차뿐만 아니라, 삶을 살아가는데 있어 집단과 개인의 격차도 꿰뚫어 보여준다고 생각합니다. 남들과는 다른 개인으로서 나 자신은 집단에 감히 선을 넘어서는 안된다는 씁쓸한 현실. ', '15742074', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15742074 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15742074 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p>재미있음그냥 기발하고 신기하고 여운남고  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15742065, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>마스터S(aem_****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:54</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','aem_****', 'jPdysfcfHWDhBHMInwdCJaIGBY15H8ExBPYvVVOyqmM=', '재미있음그냥 기발하고 신기하고 여운남고 ', '15742065', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15742065 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15742065 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
#  </div>
#  <div class="score_reple">
#  <p>새삼스럽게 ...그래서 뭐 ㅋㅋ  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15742062, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>nick(nick****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:53</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','nick****', 'tp/3QbNbl/9ikFJ8lDSpew2TxayDwqsPoBkzhwRaVs4=', '새삼스럽게 ...그래서 뭐 ㅋㅋ ', '15742062', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15742062 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15742062 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p>최우식씨 영화 마녀에서 좋게 봤는데 이번영화도 재밌네요 ㅎㅎ잘봤습니다  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15742048, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>신지웅(nove****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:52</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','nove****', 'MrBsteQOmcYIVS4m8N0XrC+pSbxRG98E9Sc7mBvaPuM=', '최우식씨 영화 마녀에서 좋게 봤는데 이번영화도 재밌네요 ㅎㅎ잘봤습니다 ', '15742048', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15742048 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15742048 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p><span class="ico_viewer">관람객</span>어... 영화보면서 이게 19금이 안걸리나..? 하는 생각도 들고.. 여태 본 영화들이랑은 뭔가 많이 다른느낌이였어요 다 보고 아 상 받을만 하구나 하는 생각이 딱 들었어요  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15742043, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>핫쿨시스템(hotc****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:52</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','hotc****', 'MZGZeCM4fJWuTkzdme1PgzT1v9IAgO9G12pLYgy/riA=', '어... 영화보면서 이게 19금이 안걸리나..? 하는 생각도 들고.. 여태 본 영화들이랑은 뭔가 많이 다른느낌이였어요 다 보고 아 상 받을만 하구나 하는 생각이 딱 들었어요 ', '15742043', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15742043 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15742043 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p>충숙의 멱살을 잡게만든 말이 영화를 함축하고 있다..  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15742040, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>Lazarus(ksun****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:51</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','ksun****', 'O/xNMOLikfhyQTG7P4ZBtosthqESNq36f8kQJbdqlmI=', '충숙의 멱살을 잡게만든 말이 영화를 함축하고 있다.. ', '15742040', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15742040 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15742040 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p>현타 너무옵니다 ㅠㅠㅠ  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15742039, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>김진현(kjj1****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:51</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','kjj1****', 'ZDumpV/KK8eK0Iq3XHUcAmpcq9rHgzqV12QbC8ro1e4=', '현타 너무옵니다 ㅠㅠㅠ ', '15742039', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15742039 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15742039 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p>충격적이고 씁쓸하다.  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15741977, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>만(jane****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:46</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','jane****', 'mKkHTLtO04ag/eT+dbM+aC4F3ane3JXzMbQReb3knyc=', '충격적이고 씁쓸하다. ', '15741977', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15741977 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15741977 count v2">1</span></strong>
#  </div>
#  </li>
#  <li>
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p>처음에는 코미디, 중반부는 스릴러, 마지막은 사회에 대해서 다시 한번 생각할 수 있게 해주는 영화  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15741973, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>김진영(wlsd****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:46</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','wlsd****', 'r1s2Rdw6lgvnfKWNaKDUkR1YU/RTgBO2f/1zgJ4UTCs=', '처음에는 코미디, 중반부는 스릴러, 마지막은 사회에 대해서 다시 한번 생각할 수 있게 해주는 영화 ', '15741973', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15741973 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15741973 count v2">1</span></strong>
#  </div>
#  </li>
#  <li class="last">
#  <div class="star_score">
#  <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
#  </div>
#  <div class="score_reple">
#  <p><span class="ico_viewer">관람객</span>와... 한순간도 빈틈이 없네요 정말 대작입니다  </p>
#  <dl>
#  <dt>
#  <em>
#  <a href="#" onclick="javascript:showPointListByNid(15741972, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#  <span>사랑인(fire****)</span>
#  </a>
#  </em>
#  <em>2019.05.30 23:45</em>
#  </dt>
#  <dd>
#  <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','fire****', 'fVbHrfkFkLNBez+iUkF/Gy8900zgFhW7kkecI3+Ib+I=', '와... 한순간도 빈틈이 없네요 정말 대작입니다 ', '15741972', 'point_after', false);return false;"><em>신고</em></a>
#  </dd>
#  </dl>
#  </div>
#  <div class="btn_area">
#  <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);"><span class="blind">공감</span></a><strong><span class="sympathy_15741972 count">2</span></strong>
#  <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);"><span class="blind">비공감</span></a><strong><span class="notSympathy_15741972 count v2">1</span></strong>
#  </div>
#  </li>
#  </ul>
#  </div>]

# %%
# 한페이지만 정해서 머신러닝은 레이블해야된다.
list2 = list1[0].findAll('li')
len(list2)
# Out:
# 10

# %%
count = 0
review_dict = dict()
for li in list2:
    review_dict[count] = {"평점": int(li.em.text), '리뷰': li.p.text}
    count += 1
    
    
    
import pandas as pd
pd.DataFrame(review_dict).T
# Out:
#                                                   리뷰  평점
# 0  이 영화는 단순히 빈부에의한 격차뿐만 아니라, 삶을 살아가는데 있어 집단과 개인의 ...  10
# 1                            재미있음그냥 기발하고 신기하고 여운남고    10
# 2                                새삼스럽게 ...그래서 뭐 ㅋㅋ     8
# 3           최우식씨 영화 마녀에서 좋게 봤는데 이번영화도 재밌네요 ㅎㅎ잘봤습니다    10
# 4  관람객어... 영화보면서 이게 19금이 안걸리나..? 하는 생각도 들고.. 여태 본...  10
# 5                    충숙의 멱살을 잡게만든 말이 영화를 함축하고 있다..    10
# 6                                     현타 너무옵니다 ㅠㅠㅠ    10
# 7                                      충격적이고 씁쓸하다.    10
# 8  처음에는 코미디, 중반부는 스릴러, 마지막은 사회에 대해서 다시 한번 생각할 수 있...  10
# 9                    관람객와... 한순간도 빈틈이 없네요 정말 대작입니다    10
