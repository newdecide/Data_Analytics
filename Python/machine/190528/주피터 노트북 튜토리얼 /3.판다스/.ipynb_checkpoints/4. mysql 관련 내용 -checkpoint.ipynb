# %%
import pymysql
import pandas as pd

# %%
conn = pymysql.connect(host = '116.125.46.109', 
                       port =27360,
                       db='mysql', 
                       user = 'root', 
                       password ='tldus12!@')
sql = "select * from user"
pd.read_sql_query(sql, conn)
# Out:
#              Host  User                                   Password  \
# 0       localhost  root  *35FDD902EFC3F979D0978463E6BD855C9CAA0AE9
# 1               %  jiny
# 2               %  root  *35FDD902EFC3F979D0978463E6BD855C9CAA0AE9
# 3       127.0.0.1  jiny
# 4  116.125.46.109  jiny
#
#   Select_priv Insert_priv Update_priv Delete_priv Create_priv Drop_priv  \
# 0           Y           Y           Y           Y           Y         Y
# 1           Y           Y           Y           Y           Y         Y
# 2           Y           Y           Y           Y           Y         Y
# 3           Y           Y           Y           Y           Y         Y
# 4           Y           Y           Y           Y           Y         Y
#
#   Reload_priv  ... max_questions max_updates max_connections  \
# 0           Y  ...             0           0               0
# 1           Y  ...             0           0               0
# 2           Y  ...             0           0               0
# ...
